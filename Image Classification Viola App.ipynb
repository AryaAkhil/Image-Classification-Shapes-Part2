# %% [markdown]
# **Overview:**
#
# This notebook aims to showcase creation of "Viola" app for image classification using fastai on shapes dataset obtained through kaggle.

# %% [markdown]
# **Data Source:**
#
# https://www.kaggle.com/cactus3/basicshapes

# %% [markdown]
# **Install Packages**

# %%
# !pip install fastai --upgrade -q
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila

# %% [markdown]
# **Import Libraries**

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %% [markdown]
# **Create Application**
#
# Use model pickle file to clasify shapes.

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl', cpu = True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

# %%
button_upload.observe(on_click_classify, names = ['data'])
VBox([widgets.Label('Select your shape!'), btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# **END**
